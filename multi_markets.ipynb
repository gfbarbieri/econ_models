# %%
import sympy as sp
from econ_models.consumer import Consumer
from econ_models.primitives.utility import Utility

# %%
t = Consumer()

# %%
t.budget_constraint.function
# Out:
# -M + p[0]*x[0] + p[1]*x[1]

# %%
t.utility.function
# Out:
# -U + beta[0]*beta[1]*x[0]**alpha[0]*x[1]**alpha[1]

# %%
t.max_utility()

# %%
t.opt_values_dict
# Out:
# {x[0]: M*alpha[0]/((alpha[0] + alpha[1])*p[0]),
#  lambda: -(M*alpha[0]/((alpha[0] + alpha[1])*p[0]))**alpha[0]*(M*alpha[1]/((alpha[0] + alpha[1])*p[1]))**alpha[1]*(alpha[0] + alpha[1])*beta[0]*beta[1]/M,
#  x[1]: M*alpha[1]/((alpha[0] + alpha[1])*p[1])}

# %%
t.get_demand(index=0)
# Out:
# M*alpha[0]/((alpha[0] + alpha[1])*p[0]) - x[0]
