# %%
# from agent_functions.utility import Cobb_Douglas_Utility
# from agent_types.consumer import Consumer
# from econmodels.functional_forms.base import BaseForms
import sympy as sp
# import pytest
from econmodels.functional_forms.utility import Utility

# %%
t = Utility(func_form='substitutes')

# %%
t.get_utility(input_values=(1, 1), constant=0)[0]
# Out:
# beta[0] + beta[1]

# %%
t.get_indifference(lhs=1)[0]
# Out:
# -beta[0]*x[0]/beta[1]

# %%
t.marginal_utility(indx=0) / t.marginal_utility(indx=1)
# Out:
# beta[0]/beta[1]

# %%
t.function
# Out:
# C - U + beta[0]*x[0] + beta[1]*x[1]

# %%
t.symboldict
# Out:
# {'coefficient': beta,
#  'constant': C,
#  'dependent': U,
#  'exponent': alpha,
#  'i': i,
#  'input': x}
