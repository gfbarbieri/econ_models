# %%
# Import the class.
from monopolist.monopolist import Monopolist

# %%
# Instantiate the class.
firm = Monopolist()

# %% [markdown]
# Now, let's compare two segmented markets which have different demand curves and include a "world market". The world market demand curve is the sum of the segmented market demand curves.

# %%
markets = [Monopolist(a=100, b=1, c=25), Monopolist(a=50, b=1/3, c=25), Monopolist(a=62.5, b=1/4, c=25)]

# %% [markdown]
# Notes:
# 1. The profit maximizing price in Market 1 is higher than the price in Market 2.
# 2. Similarly, the price elasticity of demand at the profit maximizing price in Market 1 is less elastistic (more inelastic) than the price elasticity of demand in Market 2.
# 3. Where no price discriminatino is possible (world market), the monopoly changes a price between the two segmented market prices at the profit maximizing point, which ultimately reduces the firms total profit.
# 4. The world price increases in the less reponsive market (less elastic/more inelastic) and the price decreases in the more responsive market compared to the segmented markets.
# 5. At the world price, total quantity produced by the firm is the same, but could go either way theoretically.

# %%
for i, market in enumerate(markets):
    p, q, profit = market.profit_maximization()

    print(f"Market {i+1}: The profit maximizing price per unit is {p.evalf()}.")
    print(f"Market {i+1}: The profit maximizing quantity produced is {q.evalf()}.")
    print(f"Market {i+1}: The firm's total profit is {profit.evalf()}.")
    print(f"Market {i+1}: The price elasticity of demand at the profit maximizing price and quantity is {market.price_elasticity(p_0=p, q_0=q).simplify()}")
# Out:
# Market 1: The profit maximizing price per unit is 62.5000000000000.
# Market 1: The profit maximizing quantity produced is 37.5000000000000.
# Market 1: The firm's total profit is 1406.25000000000.
# Market 1: The price elasticity of demand at the profit maximizing price and quantity is -5/3
# Market 2: The profit maximizing price per unit is 37.5000000000000.
# Market 2: The profit maximizing quantity produced is 37.5000000000000.
# Market 2: The firm's total profit is 468.750000000000.
# Market 2: The price elasticity of demand at the profit maximizing price and quantity is -3.00000000000000
# Market 3: The profit maximizing price per unit is 43.7500000000000.
# Market 3: The profit maximizing quantity produced is 75.0000000000000.
# Market 3: The firm's total profit is 1406.25000000000.
# Market 3: The price elasticity of demand at the profit maximizing price and quantity is -2.33333333333333

# %% [markdown]
# Now, let's plot these functions. To do so, we have to set parameters for the demand and cost functions.

# %%
k = sp.plot(
    firm.get_marginal_cost(),
    firm.get_demand(inverse=True),
    firm.get_marginal_revenue(p=firm.get_demand(inverse=True)),
    (firm.q, 0, 50),
    xlabel='Quantity',
    ylabel='Price',
    xlim=(0, 50),
    ylim=(0, 50),
    annotations=[{'text':'MR', 'xy':(25, 0), 'xycoords':'data', 'xytext':(25,1), 'textcoords':'data'}]
)

# %%
fig, ax = plt.subplots()
ax.plot(k)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: float() argument must be a string or a number, not 'Plot'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# /var/folders/j_/p28zw__n52g6yjt754l8zdw00000gn/T/ipykernel_29768/4115986314.py in <module>
#       1 fig, ax = plt.subplots()
# ----> 2 ax.plot(k)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1632         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633         for line in lines:
# -> 1634             self.add_line(line)
#    1635         self._request_autoscale_view(scalex=scalex, scaley=scaley)
#    1636         return lines
#
# ...

# %% [markdown]
# Now, let's set parameter values for the cost and demand functions and redo some of the examples.  the cost and demand function parameter values. The linear demand function parameters will give the intercept a value of 100 and a slope of -1. The marginal cost parameter will be set to 25.

# %% [markdown]
# Print the total revenue, total cost, profit, and demand functions.

# %%
# Create instance of Monopolist class.
firm = Monopolist(a = 100, b = 1, c = 25)

# Print the total revenue, total cost functions.
print(firm.total_revenue)
print(firm.total_cost)

# Print the profit function.
print(firm.get_profit())

# Print the demand function.
print(firm.demand)
print(firm.get_demand(inverse=False))
print(firm.get_demand(inverse=True))
# Out:
# p*q
# 25*q
# p*q - 25*q
# -p - q + 100
# 100 - p
# 100 - q

# %% [markdown]
# Calculate profit maximizing p, q, and profit.

# %%
firm.profit_maximization()
# Out:
# (125/2, 75/2, 5625/4)

# %% [markdown]
# Calculate price elasticity of demand at the profit maximizing price.

# %%
p, q, profit = firm.profit_maximization()
firm.price_elasticity(p_0=p, q_0=q)
# Out:
# -3/5

# %%
# Create instance of Monopolist class.
firm = Monopolist(a = 50, b = 1/3, c = 25)

# Print the total revenue, total cost functions.
print(firm.total_revenue)
print(firm.total_cost)

# Print the profit function.
print(firm.get_profit())

# Print the demand function.
print(firm.demand)
print(firm.get_demand(inverse=False))
print(firm.get_demand(inverse=True))

# Maximize profit
p, q, profit = firm.profit_maximization()

# Calculate elasticity
firm.price_elasticity(p_0=p, q_0=q)
# Out:
# p*q
# 25*q
# p*q - 25*q
# -p - 0.333333333333333*q + 50
# 150.0 - 3.0*p
# 50.0 - 0.333333333333333*q
# -3.00000000000000

# %%
# Create instance of Monopolist class.
firm = Monopolist(a = 100, b = 2, c = 25)

# Print the total revenue, total cost functions.
print(firm.total_revenue)
print(firm.total_cost)

# Print the profit function.
print(firm.get_profit())

# Print the demand function.
print(firm.demand)
print(firm.get_demand(inverse=False))
print(firm.get_demand(inverse=True))

# Maximize profit
p, q, profit = firm.profit_maximization()

# Calculate elasticity
firm.price_elasticity(p_0=p, q_0=q)
# Out:
# p*q
# 25*q
# p*q - 25*q
# -p - 2*q + 100
# 50 - p/2
# 100 - 2*q
# -3/20

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=f1745333-6771-4d8a-902a-76f33b254468' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
