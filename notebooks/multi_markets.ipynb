# %%
import sympy as sp
from models.consumer import Consumer

# %%
t = Consumer()

# %%
t.budget_constraint.symbol_dict
# Out:
# {'dependent': M, 'input': x, 'coeff': p, 'exponent': alpha, 'i': i}

# %%
t.utility.symbol_dict
# Out:
# {'dependent': U, 'input': x, 'coeff': beta, 'exponent': alpha, 'i': i}
